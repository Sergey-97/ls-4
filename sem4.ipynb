# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("kc_house_data.csv", sep=',', encoding='utf-8')
# # установка локали для форматирования денежных значений
# locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
# # функция для форматирования денежных значений
# def format_price(price):return locale.currency(price, grouping=True)
# # применение функции к столбцу "price" с помощью метода .map()
# df['price'] = df['price'].map(format_price)
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 df = pd.read_csv("kc_house_data.csv", sep=',', encoding='utf-8')
#       6 # # установка локали для форматирования денежных значений
#       7 # locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
#       8 # # функция для форматирования денежных значений
#       9 # def format_price(price):return locale.currency(price, grouping=True)
#      10 # # применение функции к столбцу "price" с помощью метода .map()
#      11 # df['price'] = df['price'].map(format_price)
#      12 df.head(3)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kc_house_data.csv'

# %% [markdown]
# ##### 1.2. Изучите стоимости недвижимости

# %%
df["price"].min(), df["price"].mean().round(2), df["price"].max()
# Out:
# (75000.0, 540088.14, 7700000.0)

# %%
plt.figure(figsize=(10,4))
sns.histplot(df['price'])
plt.ticklabel_format(style='plain')
plt.title('Распределение стоимости недвижимости')
plt.xlabel('Стоимость')
plt.ylabel('Количество');

# %% [markdown]
# ###### 1.3. Изучите распределение квадратуры жилой

# %%
plt.figure(figsize=(10, 4))
sns.histplot(df['sqft_living'])
plt.ticklabel_format(style='plain')
plt.title('Распределение жилой площади')
plt.xlabel('Площадь')
plt.ylabel('Количество');

# %% [markdown]
# ###### 1.4. Изучите распределение года постройки

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df['yr_built'])
plt.title('Распределение года постройки')
plt.xlabel('Год постройки')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %%
df.head(1)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3        1.0         1180
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
#
#    sqft_lot15
# 0        5650
#
# [1 rows x 21 columns]

# %% [markdown]
# #### Условие 2: 2 задача
# ###### 2.1. Изучите распределение домов от наличия вида на набережную

# %%
data1 = df['waterfront'].value_counts()
data1
# Out:
# waterfront
# 0    21450
# 1      163
# Name: count, dtype: int64

# %%
labels = ['Есть вид', 'Нет вида']
plt.pie(data1, autopct='%1.1f%%', labels=labels)
plt.title('Распределение домов от наличия вида на набережную')
# Out:
# Text(0.5, 1.0, 'Распределение домов от наличия вида на набережную')

# %% [markdown]
# ###### 2.2. Изучите распределение этажей домов

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x=data2.index, y=data2)
plt.title('Распределение этажей домов')
plt.xlabel('Количество этажей')
plt.ylabel('Количество');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 plt.figure(figsize=(6, 4))
# ----> 2 sns.barplot(x=data2.index, y=data2)
#       3 plt.title('Распределение этажей домов')
#       4 plt.xlabel('Количество этажей')
#
# NameError: name 'data2' is not defined

# %% [markdown]
# ###### 2.3. Изучите распределение состояния домов

# %%
data3 = df['condition'].value_counts()
data3
# Out:
# condition
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x=data3.index, y=data3)
plt.title('Распределение состояния домов')
plt.xlabel('Состояние дома')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %% [markdown]
# #### Условие 3: 3 задача
# ###### Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# ###### Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
sns.jointplot(x=df['price'], y=df['sqft_living'], kind='reg')
plt.xlabel('Стоимость')
plt.ylabel('Площадь (кв.м)');

# %% [markdown]
# ##### Вывод: На данном графике видно, что с увеличением площади квартиры растет ее цена.

# %%
sns.boxplot(x=df['price'], y=df['floors'].astype('str'), whis=1.5)
plt.xlabel('Стоимость')
plt.ylabel('Этажность')
plt.title('Влияние количества этажей на стоимость');

# %% [markdown]
# ##### Вывод: Дома с 2,5 этажами стоят дороже.

# %%
sns.boxplot(x=df['price'], y=df['grade'].astype('str'), whis=1.5)
plt.xlabel('Стоимость')
plt.ylabel('Оценка недвижемости')
plt.title('Влияние оценки недвижимости на стоимость');

# %% [markdown]
# ##### Вывод: Дома, с оценкой "13" за конструкцию и дизайн, обладают наивысшей стоимостью.

# %%
sns.boxplot(x=df['price'], y=df['view'].astype('str'), whis=1.5)
plt.xlabel('Стоимость')
plt.ylabel('Вид')
plt.title('Влияние вида недвижимости на стоимость');

# %% [markdown]
# ##### Вывод: Дома с оценкой вида ""4" стоят дороже.
